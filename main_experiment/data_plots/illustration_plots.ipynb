# %%
import sys  
sys.path.insert(0, '/Users/navinlr/Desktop/')

# %%
# from dataset_creation import dataset_creator as data_generator
# from feature_extract import turntake_extractor as feat_extractor
# import constants

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy import genfromtxt


sns.set(rc={'figure.figsize':(11.7,3.27)})

# %%
my_data = genfromtxt('/Users/navinlr/Desktop/sampl1.csv', delimiter=',')[:1000]
print(my_data)
# Out:
# [-0.90222685 -0.91392799 -0.91392799 -0.77128551 -0.77128551 -0.91392799
#  -0.91392799 -0.91392799 -0.91392799 -0.91392799 -0.77128551 -0.77128551
#  -0.77128551 -0.91392799 -0.91392799 -0.91392799 -0.91392799 -0.91392799
#  -0.91392799 -0.91392799 -0.90222685 -0.77128551 -0.77128551 -0.77128551
#  -0.77128551 -0.62864302 -0.77128551 -0.77128551 -0.77128551 -0.77128551
#  -0.77128551 -0.77128551 -0.77128551 -0.62864302 -0.62864302 -0.62864302
#  -0.77128551 -0.77128551 -0.77128551 -0.77128551 -0.75958436 -0.62864302
#  -0.62864302 -0.62864302 -0.62864302 -0.62864302 -0.62864302 -0.77128551
#  -0.77128551 -0.77128551 -0.62864302 -0.77128551 -0.77128551 -0.62864302
#  -0.77128551 -0.62864302 -0.77128551 -0.62864302 -0.62864302 -0.62864302
#  -0.61694187 -0.34335804 -0.34335804 -0.34335804 -0.34335804 -0.34335804
#  -0.34335804 -0.34335804 -0.20071555 -0.05807306 -0.05807306  0.08456943
#  -0.05751586 -0.05751586 -0.05751586 -0.20015835  0.08456943 -0.05751586
# ...

# %%
#Plots
ax = sns.lineplot(x=np.arange(len(my_data)), y=my_data, label="acclerometer-recording")
# plt.ylabel('Probability Density', fontsize=20)
# plt.xlabel('', fontsize=20)
plt.tick_params(labelsize=15)
plt.show()
